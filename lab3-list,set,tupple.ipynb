# %% [markdown]
# <a href="https://colab.research.google.com/github/MumtahinaMozumder/Python/blob/main/lab3-list%2Cset%2Ctupple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L=[3,2,4,-0,0,5]
print(L)
# Out:
# [3, 2, 4, 0, 0, 5]

# %%
print (L[2])
# Out:
# 4

# %%
print(L[-1])
# Out:
# 5

# %%
L[2]=100

# %%
print(L)
# Out:
# [3, 2, 100, 0, 0, 5]

# %%
print(L[-5])
# Out:
# 2

# %%
print[L[-9]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_4159/2026354443.py in <cell line: 0>()
# ----> 1 print[L[-9]]
#
# IndexError: list index out of range

# %%
L[-9]=100
print(L)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_4159/3562403469.py in <cell line: 0>()
# ----> 1 L[-9]=100
#       2 print(L)
#
# IndexError: list assignment index out of range

# %%
L[3:6]
# Out:
# [0, 0, 5]

# %%
L[::]
# Out:
# [3, 2, 100, 0, 0, 5]

# %%
L[6:]
# Out:
# []

# %%
L[5:]
# Out:
# [5]

# %%
L[-5:-4]
# Out:
# [2]

# %%
L[:5]
# Out:
# [3, 2, 100, 0, 0]

# %%
L[::-1]
# Out:
# [5, 0, 0, 100, 2, 3]

# %%
num= 7127
num_str =str(num)
rev_num_str=''.join(reversed(num_str)) #rev_num_str=num_st[::1]
if num_str== rev_num_str:
  print("Pallindrome")
else:
  print("not pALLINDROME")
# Out:
# not pALLINDROME

# %%
num=int(input("num="))
num_str=str(num)
print("pallindrome " if num_str==num_str[::-1] else "not pallindrom")
# Out:
# num=444
# pallindrome

# %%
n=int(input("enter n:"))
L=[]
for i in range(n):
  num=int(input(f"enter{i+1}th number:"))
  L.append(num)
mean=sum(L)/len(L)
print(mean)
# Out:
# enter n:5
# enter1th number:45
# enter2th number:62
# enter3th number:12
# enter4th number:45
# enter5th number:54
# 43.6

# %%
L=[100,0,-1,2,-5]
for i in range(len(L)):
 if L[i]<0:
  L[i]=L[i]*-1
print(L)
# Out:
# [100, 0, 1, 2, 5]
