# %% [markdown]
# <a href="https://colab.research.google.com/github/MumtahinaMozumder/Python/blob/main/lab2(ifelse_and_conditional).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input())
if a%2 == 0:
  print(f"{a} is even")
else:
 print(f"{a} is odd")
# Out:
# 5
# 5 is odd

# %%
b=int(input())
if b>=93 :
  print(f"{b} refers to GRADE A")
elif (b<93) & (b>=60):
  print(f"{b} refers to pass mark")
else:
  print(f"{b} refers to fail")
# Out:
# 50
# 50 refers to fail

# %%
d=int(input())
e=int(input())
F=int(input())
if F>d & F>e:
  print(f"{F} is the largest")
elif d>F & d>e:
  print(f"{d} is the largest")
elif e>F & e>d:
  print(f"{e} is the largest")
else:
  print(f"{e},{F},{d} are equal")
# Out:
# 5
# 5
# 5
# 5,5,5 are equal

# %%
d,e,f=map(int,input().split())
if F>d & F>e & F!=d & F!=e:
  print(f"{F} is the largest")
elif d>F & d>e & d!=F & d!=e:
  print(f"{d} is the largest")
elif e>F & e>d & F!=e & d!=e: #there are some errors
  print(f"{e} is the largest")
else:
  print(f"{e},{F},{d} are equal")
# Out:
# 5 67 5
# 67,5,5 are equal

# %%
d,e,f=map(int,input().split())
if f!=d & f!=e:
  if(f>d & f>e):
   print(f"{f} is the largest")
elif d!=f & d!=e:
  if(d>F & d>e):
   print(f"{d} is the largest")
elif F!=e & d!=e:
  if(e>F & e>d ): #there are some errors
   print(f"{e} is the largest")
else:
  print(f"{e},{f},{d} are equal")
# Out:
# 5 0 5
# 0,5,5 are equal

# %%
d,e,f=map(int,input().split()) #using max built in function
print(max(d,e,f))
# Out:
# 5 4 6
# 6

# %%
num = 9
i = 1
while i<=10:
  print(num*i,end=" ")
  i+=1
# Out:
# 9 18 27 36 45 54 63 72 81 90

# %%
string1="this is a string"
i=0
cnt=0
while i<len(string1):
  if string1[i]=='a' or string1[i]=='e' or string1[i]=='i' or string1[i]=='o' or string1[i]=='u':
    cnt+=1
  i+=1
print(cnt)
# Out:
# 4

# %%
string1="this is a string"
i=0
cnt=0
while i<len(string1):
  if string1[i] in "aeiou":
    cnt+=1
  i+=1
print(cnt)
# Out:
# 4

# %%
string1="this is a string"
string1=string1.lower()

cnt=0
for s in string1:
  if s in "aeiou":
   cnt+=1
print(cnt)
# Out:
# 4

# %%
string1="this is a string"
string1=string1.lower()

cnt=0
for s in string1:
  if s in "aeiou":
   cnt+=1 #have to convert it in upper
print(cnt)

# %%
for i in range(7):
 print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
s="*"
n=5

for i in range(n):
 print(s*(i+1))
# Out:
# *
# **
# ***
# ****
# *****

# %%
n=5
for i in range (1,n+1):
 for j in range (i):
   print("*",end=" ")
 print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
n=5
for i in range (1,n+1):
 for j in range (i,n+1):
  print("*",end=" ")
 print()
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *
