# %% [markdown]
# <a href="https://colab.research.google.com/github/MumtahinaMozumder/Python/blob/main/lab1(I_0_and_datatypes).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Output with Python

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
print('hello world')

print("hello",end ='// ')
print("world")
# Out:
# hello world
# hello world
# hello// world

# %% [markdown]
# ##Output with single variable

# %%
a=5
print("a=",a)
# Out:
# a= 5

# %%
print(a)
# Out:
# 5

# %%
print("a =",a,"which is an integer")  #comma addes an extra space with the output
# Out:
# a = 5 which is an integer

# %%
print("a ={} is an int".format(a)) #dot format calculates inside the bracket
# Out:
# a =5 is an int

# %%
print(f"a ={a} which is an int")
# Out:
# a =5 which is an int

# %%
#print("a"+a)  #'+' concatanation,only strings can be concatenated
print("a " + str(a))
# Out:
# a 5

# %% [markdown]
# ##Output with double variable

# %%
a,b= 5,6
print(a,b)
print("a",a,"b",b)
print("a "+str(a),"b "+str(b))
print("a = {} b = {}".format(a,b))
print(f"a={a} b={b}")
# Out:
# 5 6
# a 5 b 6
# a 5 b 6
# a = 5 b = 6
# a=5 b=6

# %% [markdown]
# #Input with single variable

# %%
a= input()
print(f"a ={a} and which Type={type(a)}")
print("a={} and type= {}".format(a,type(a)))
# Out:
# 2
# a =2 and which Type=<class 'str'>
# a=2 and type= <class 'str'>

# %%
a = int(input())
print(f"a = {a} and type ={type(a)}")
# Out:
# 5
# a = 5 and type =<class 'int'>

# %%
a =int(input("enter an input"))
print(f"a ={a} and type={type(a)}")
# Out:
# enter an input5
# a =5 and type=<class 'int'>

# %%
a =int(input("enter an input"))
print(f"a ={a} and type={type(a)}")
# Out:
# enter an input7
# a =7 and type=<class 'int'>

# %%
a=input()
b=input()
print(f"a ={a} and b={b}")
# Out:
# 5
# 6
# a =5 and b=6

# %%
a=input()
b=str(input())
print(f"a ={a} and b={b}")
print(f"type= {type(a)} and type ={type(b)}")
# Out:
# 5
# 6
# a =5 and b=6
# type= <class 'str'> and type =<class 'str'>

# %% [markdown]
# > user always takes input as string ,no matter its number or anything else

# %%
a=int(a) #did type casting(string to integer)

# %%
a #output came exact the number,not as the string
# Out:
# 5
